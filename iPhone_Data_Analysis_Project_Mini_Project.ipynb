# %%
# Importing PANDAS package

import pandas as pd

# %%
# Creating a dataframe named 'appleDf'

appleDf = pd.read_csv('apple_products.csv')

# %%
# Displays top 10 values of the dataframe

appleDf.head(10)
# Out:
#                                         Product Name  \
# 0                  APPLE iPhone 8 Plus (Gold, 64 GB)
# 1           APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2               APPLE iPhone 8 Plus (Silver, 256 GB)
# 3                    APPLE iPhone 8 (Silver, 256 GB)
# 4                      APPLE iPhone 8 (Gold, 256 GB)
# 5                APPLE iPhone 8 Plus (Silver, 64 GB)
# 6            APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                APPLE iPhone 8 (Space Grey, 256 GB)
# 8                APPLE iPhone XS Max (Silver, 64 GB)
# 9  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# Displays count of values in each column

appleDf.count()
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
# Displays the status of nulls

appleDf.isnull()
# Out:
#     Product Name  Product URL  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False        False  False       False  False                False
# 1          False        False  False       False  False                False
# 2          False        False  False       False  False                False
# 3          False        False  False       False  False                False
# 4          False        False  False       False  False                False
# ..           ...          ...    ...         ...    ...                  ...
# 57         False        False  False       False  False                False
# 58         False        False  False       False  False                False
# 59         False        False  False       False  False                False
# 60         False        False  False       False  False                False
# 61         False        False  False       False  False                False
#
# ...

# %%
# Displays the status of missing values

appleDf.isna()
# Out:
#     Product Name  Product URL  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False        False  False       False  False                False
# 1          False        False  False       False  False                False
# 2          False        False  False       False  False                False
# 3          False        False  False       False  False                False
# 4          False        False  False       False  False                False
# ..           ...          ...    ...         ...    ...                  ...
# 57         False        False  False       False  False                False
# 58         False        False  False       False  False                False
# 59         False        False  False       False  False                False
# 60         False        False  False       False  False                False
# 61         False        False  False       False  False                False
#
# ...

# %%
# Displays all the columns of the dataframe

appleDf.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Star Rating', 'Ram'],
#       dtype='object')

# %%
# Displays dataframe information

appleDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 5.5+ KB

# %%
# Displays Maximum value of Mrp

appleDf['Mrp'].max()
# Out:
# 149900

# %%
# Displays Minimum value of Mrp


appleDf['Mrp'].min()
# Out:
# 39900

# %%
appleDf['Star Rating'].max()
appleDf['Star Rating'].min()
# Out:
# 4.5

# %%
# Display the products against the searched price

appleDf[appleDf['Mrp'] == 149900]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
appleDf[appleDf['Mrp'] == 39900]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
appleDf[appleDf['Ram'] == '6 GB']
# Out:
#                                       Product Name  \
# 25  APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27          APPLE iPhone 12 Pro (Graphite, 256 GB)
# 29                 APPLE iPhone 12 (White, 128 GB)
# 30          APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31      APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32      APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 35                 APPLE iPhone 12 (Black, 128 GB)
# 36                  APPLE iPhone 12 (Blue, 128 GB)
# 37        APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 38               APPLE iPhone 12 Mini (Red, 64 GB)
# 39          APPLE iPhone 12 Pro Max (Gold, 128 GB)
# 40                 APPLE iPhone 12 (Green, 128 GB)
# 42                  APPLE iPhone 12 (White, 64 GB)
# 43                  APPLE iPhone 12 (Black, 64 GB)
# 44                   APPLE iPhone 12 (Red, 128 GB)
# 46      APPLE iPhone 12 Pro (Pacific Blue, 128 GB)
# 47  APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)
# ...

# %%
# Used to check the datatype

type(appleDf['Product Name'])
# Out:
# pandas.core.series.Series

# %%
# Casted the series into list for operations

list(appleDf['Product Name'])[54][6:15].upper().strip()
# Out:
# 'IPHONE SE'

# %%
# Creating a new df or a column

appleDf['Model Name'] = appleDf['Product Name'].str[6:15]
appleDf.head(5)
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
# Displays products based on star ratings in descending order

appleDf.sort_values(by = ['Star Rating'], ascending = False)
# Out:
#                                          Product Name  \
# 20    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17        APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16   APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15              APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                                ...
# 45                APPLE iPhone 12 Mini (Black, 64 GB)
# 28                APPLE iPhone 12 Mini (White, 64 GB)
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 41         APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 27             APPLE iPhone 12 Pro (Graphite, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ...

# %%
# Similarly we can display products with prices (low -> high)

appleDf.sort_values(by = ['Mrp'], ascending = True)
# Out:
#                                       Product Name  \
# 52                  APPLE iPhone SE (White, 64 GB)
# 57                  APPLE iPhone SE (Black, 64 GB)
# 53                 APPLE iPhone SE (Black, 128 GB)
# 55                   APPLE iPhone SE (Red, 128 GB)
# 54                 APPLE iPhone SE (White, 128 GB)
# ..                                             ...
# 25  APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 21    APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 19        APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 24            APPLE iPhone 12 Pro (Silver, 512 GB)
# 41      APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# ...
